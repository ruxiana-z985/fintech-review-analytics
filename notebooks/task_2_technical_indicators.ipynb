# %% [markdown]
# # Task 2: Technical Indicators
#
# This notebook loads stock price data, computes indicators, and visualizes price action for the Nova Financial Solutions challenge.

# %%
from src.data_loader import copy_price_data, load_stock_prices
from src.indicators import compute_indicators

copy_price_data()
aapl = load_stock_prices('AAPL')
aapl_indicators = compute_indicators(aapl)
aapl_indicators.tail()

# %%
aapl_indicators[['Close', 'sma_20', 'sma_50', 'ema_20', 'rsi_14', 'macd', 'macd_signal']].tail(20)
